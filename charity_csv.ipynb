# %%
#import dependencies
import pandas as pd
import datetime
from sqlalchemy import create_engine

# %%
# import charity data
organizations = pd.read_csv("data/CLEAN_charity_data.csv")
organizations.head()
# Out:
#    ascore                   category  \
# 0   100.0                Environment
# 1    89.0  Arts, Culture, Humanities
# 2    70.0                   Religion
# 3    93.0  Arts, Culture, Humanities
# 4   100.0             Human Services
#
#                                          description         ein     tot_exp  \
# 0  Working with Oregonians to enhance our quality...  93-0642086    917313.0
# 1  Serving the metropolitan Baltimore area and th...  31-1770828   5053059.0
# 2  VSS Catholic Communications is dedicated to an...  91-1857425   1891500.0
# 3  The mission of the Utah Symphony & Opera is to...  51-0145980  22506582.0
# 4  Funded solely by the footwear industry, Two Te...  22-2579809   5594243.0
#
#    admin_exp_p  fund_eff  fund_exp_p  program_exp_p  fscore  ...  \
# 0        0.101      0.18       0.184          0.714   88.61  ...
# 1        0.231      0.05       0.032          0.735   82.85  ...
# 2        0.114      0.17       0.197          0.687   86.74  ...
# ...

# %%
#rename columns
organizations = organizations.rename(columns = {"tot_exp":"total_expenses", "admin_exp_p":"admin_expense_percentage",
                                               "fund_expense_percentage": "fundraising_expense_percentage", "program_exp_p": "program_expense_percentage",
                                               "leader_comp": "ceo_compensation", "leader_compensation_percentage": "ceo_compensation_percentage",
                                               "program_exp": "program_expenses", "funding_expenses": "fundraising_expenses",
                                               "admin_exp": "administrative_expenses", "ascore": "accountability_score",
                                               "fscore": "financial_score", "tot_rev": "total_revenue",
                                               "leader": "ceo"})
organizations.head()
# Out:
#    accountability_score                   category  \
# 0                 100.0                Environment
# 1                  89.0  Arts, Culture, Humanities
# 2                  70.0                   Religion
# 3                  93.0  Arts, Culture, Humanities
# 4                 100.0             Human Services
#
#                                          description         ein  \
# 0  Working with Oregonians to enhance our quality...  93-0642086
# 1  Serving the metropolitan Baltimore area and th...  31-1770828
# 2  VSS Catholic Communications is dedicated to an...  91-1857425
# 3  The mission of the Utah Symphony & Opera is to...  51-0145980
# 4  Funded solely by the footwear industry, Two Te...  22-2579809
#
#    total_expenses  admin_expense_percentage  fund_eff  \
# 0        917313.0                     0.101      0.18
# 1       5053059.0                     0.231      0.05
# 2       1891500.0                     0.114      0.17
# ...

# %%
#drop description column to decrease size of file
organizations_clean = organizations.drop("description", axis=1)

organizations_clean.head()
# Out:
#    accountability_score                   category         ein  \
# 0                 100.0                Environment  93-0642086
# 1                  89.0  Arts, Culture, Humanities  31-1770828
# 2                  70.0                   Religion  91-1857425
# 3                  93.0  Arts, Culture, Humanities  51-0145980
# 4                 100.0             Human Services  22-2579809
#
#    total_expenses  admin_expense_percentage  fund_eff  \
# 0        917313.0                     0.101      0.18
# 1       5053059.0                     0.231      0.05
# 2       1891500.0                     0.114      0.17
# 3      22506582.0                     0.092      0.08
# 4       5594243.0                     0.126      0.12
#
#    fundraising_expense_percentage  program_expense_percentage  \
# 0                           0.184                       0.714
# 1                           0.032                       0.735
# 2                           0.197                       0.687
# ...

# %%
#create connection to our MongoDB
import pymongo
from pymongo import MongoClient
conn = "mongodb+srv://falcon2020:Falcon20@charity-cluster-homax.azure.mongodb.net/test?retryWrites=true&w=majority"
client = pymongo.MongoClient(conn)

# %%
#upload to MongoDB

col = client['charity_orgs']['charity_data']

data = organizations_clean.to_dict(orient='records')  # Here's our added param..

col.insert_many(data)
